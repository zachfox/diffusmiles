# %%
import sys
sys.path.append('../')

import torch
import numpy as np

# %matplotlib notebook 
import matplotlib.pyplot as plt

from importlib import reload
import blackout_utils as bu

# %%
device = 'cpu'

# %%
reload(bu)
batch = np.random.randint(0,64, size=(3,10))
cdfs, reverse_rates, observation_times = bu.get_binomial_corrupter()

# %%
reload(bu)
cbatch, br, times = bu.noisify_batch(torch.Tensor(batch), device, torch.Tensor(cdfs), reverse_rates, observation_times, 1000, 64)
# Out:
# tensor([[400],
#         [518],
#         [513]])

# %%
cbatch
# Out:
# tensor([[54, 40, 41, 29, 33, 27,  5, 59, 46, 26],
#         [11, 11, 11, 18,  8, 21, 12,  4,  1, 12],
#         [23,  5,  8, 20, 12,  1,  8,  7,  9, 25]], dtype=torch.int32)

# %%
batch
# Out:
# array([[56, 41, 42, 30, 37, 30,  5, 61, 46, 26],
#        [22, 29, 33, 55, 19, 35, 45,  8,  2, 41],
#        [55, 17, 25, 52, 25,  2, 32, 22, 25, 63]])

# %%
diff = torch.Tensor(batch)-cbatch

# %%
diff
# Out:
# tensor([[ 2.,  1.,  1.,  1.,  4.,  3.,  0.,  2.,  0.,  0.],
#         [11., 18., 22., 37., 11., 14., 33.,  4.,  1., 29.],
#         [32., 12., 17., 32., 13.,  1., 24., 15., 16., 38.]])

# %%
br
# Out:
# array([[ 2.,  1.,  1.,  1.,  4.,  3.,  0.,  2.,  0.,  0.],
#        [11., 18., 22., 37., 11., 14., 33.,  4.,  1., 29.],
#        [32., 12., 17., 32., 13.,  1., 24., 15., 16., 38.]])

# %%
(reverse_rates[:,:,482] - reverse_rates[:,:,481]).sum()
# Out:
# 0.0

# %%
sampling_probs = np.clip( np.exp(-observation_times))

# %%
t = observation_times
offset=.01
sampling_prob = np.clip( np.exp(-t)*(1.-np.exp(-t)), offset, np.inf)

# %%
f,ax = plt.subplots()
ax.plot(observation_times)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
f,ax = plt.subplots()
ax.plot(sampling_prob)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
x = {'a':[1],'b':'lamabama'}

# %%
def y(q, a, b):
    print(q,a,b)
    return
y(1,**x)
# Out:
# 1 [1] lamabama
